# %% [markdown]
# # 🔬 FD001 Executed Analysis
#
# Ground-truth evaluation analysis for the NASA C-MAPSS FD001 test set. True RUL labels are used only for benchmark evaluation.

# %%
from pathlib import Path
import pandas as pd
from src.aerospace_analytics import build_evaluation_table, summarize

rul = pd.read_csv(Path('data/raw/RUL_FD001.txt'), header=None, names=['true_rul_cycles'])
rul['engine_id'] = range(1, len(rul) + 1)
result = build_evaluation_table(rul[['engine_id', 'true_rul_cycles']])
summarize(result)

# %% [markdown]
# ## Expected evidence
#
# The committed `reports/` folder contains the rendered result table and visualization produced from the FD001 evaluation artifact.
